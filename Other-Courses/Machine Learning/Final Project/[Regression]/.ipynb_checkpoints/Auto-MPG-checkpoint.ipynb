# %% [markdown]
# # Import Libraries

# %%
# Import Basic Libraries
import os
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from collections import Counter
from pandas.plotting import scatter_matrix

# Scikit Packages
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder

# Train Data
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# ANN
#import tensorflow as tf
#import keras
#from keras.models import Sequential
#from keras.layers import Dense
#from keras.callbacks import EarlyStopping
#from keras.callbacks import ModelCheckpoint, TensorBoard
#from keras.layers import LeakyReLU, PReLU, ELU

# %matplotlib inline

from scipy import stats
from scipy.stats import norm, skew

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id = "2"></a><br>
# # Load Dataset

# %%
data = pd.read_csv('auto-mpg.csv')
data.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala
# 7       1          plymouth fury iii
# 8       1           pontiac catalina
# 9       1         amc ambassador dpl

# %%
data.tail(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                    car name
# 388          82       1  chrysler lebaron medallion
# 389          82       1              ford granada l
# 390          82       3            toyota celica gt
# 391          82       1           dodge charger 2.2
# 392          82       1            chevrolet camaro
# 393          82       1             ford mustang gl
# 394          82       2                   vw pickup
# 395          82       1               dodge rampage
# 396          82       1                 ford ranger
# 397          82       1                  chevy s-10

# %% [markdown]
#  ### Attribute Information:
#
#  1. **MPG**: The fuel economy of an automobile is the relationship between the distance traveled and the amount of fuel consumed by the vehicle. MPG is continuous from 9 to 48 (Continuous).
#
#  2. **Cylinders**: A cylinder is the power unit of an engine; it's the chamber where the gasoline is burned and turned into power. Number of cylinder continuous from 3 to 8 (Multi-Valued Discrete)
#
#  3. **Displacement**: Engine displacement is the measure of the cylinder volume swept by all of the pistons of a piston engine, excluding the combustion chambers. Displacement is continuous from 68 to 455 (Continuous)
#
#  4. **Horsepower**: Horsepower is a unit of power used to measure the forcefulness of a vehicle's engine. Horse power continuous from 46 to 230 (Continuous).
#
#  5. **Weight**: The weight of an object is related to the amount of force acting on the object, either due to gravity or to a reaction force that holds it in place. The weight of car continuous from 1613 to 5140 (Continuous).
#
#  6. **Acceleration**: Is the rate of change of velocity of an object with respect to time. It continuous from 8 to 25 (Continuous).
#
#  7. **Model Year**: Is the year in which product is manufactured. The year ranges from 1970 to 1982 (Multi-Valued Discrete)
#
#  8. **Origin**: multi-valued discrete (USA - Japan - Euro)
#
#  9. **Car Name**: string (unique for each instance)

# %% [markdown]
# <a id = "2"></a><br>
# # Data Exploration

# %%
print('The dataset contains {0} rows and {1} columns.'.format(data.shape[0], data.shape[1]))
# Out:
# The dataset contains 398 rows and 9 columns.

# %%
# Checking for duplicated data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * **From the above it is clearly observed that there is no duplicate data present in dataset.**

# %%
# We can see horsepower isn't shown here, we will see why soon
data.describe().round(4)
# Out:
#             mpg  cylinders  displacement     weight  acceleration  model year  \
# count  398.0000   398.0000      398.0000   398.0000      398.0000    398.0000
# mean    23.5146     5.4548      193.4259  2970.4246       15.5681     76.0101
# std      7.8160     1.7010      104.2698   846.8418        2.7577      3.6976
# min      9.0000     3.0000       68.0000  1613.0000        8.0000     70.0000
# 25%     17.5000     4.0000      104.2500  2223.7500       13.8250     73.0000
# 50%     23.0000     4.0000      148.5000  2803.5000       15.5000     76.0000
# 75%     29.0000     8.0000      262.0000  3608.0000       17.1750     79.0000
# max     46.6000     8.0000      455.0000  5140.0000       24.8000     82.0000
#
#          origin
# count  398.0000
# mean     1.5729
# std      0.8021
# min      1.0000
# 25%      1.0000
# 50%      1.0000
# 75%      2.0000
# max      3.0000

# %% [markdown]
# ### Summary Statistics
# - **Mean**: Balance Point
# - **Median**: Middle Value "when ordered"
# - **Variance**: The average of the squared distance of the mean
# - **Standard Deviation**: The square root of the variance
# - **Skewness**: A measure that describes the contrast of one tail versus the other tail. For example, if there are more high values in your distribution than low values then your distribution is 'skewed' towards the high values.
# - **Kurtosis**: A measure of how 'fat' the tails in the distribution are.

# %%
data.skew()
# Out:
# mpg             0.457066
# cylinders       0.526922
# displacement    0.719645
# weight          0.531063
# acceleration    0.278777
# model year      0.011535
# origin          0.923776
# dtype: float64

# %%
data['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
# visualizing our dependent variable for outliers and skewnwss
plt.figure(figsize = (15, 4))

plt.subplot(1, 2, 1)
sns.boxplot(data['mpg'])
plt.title("Boxplot for outliers detection", fontweight = 'bold')

plt.subplot(1, 2, 2)
sns.distplot(data['mpg'])
plt.title("Distribution plot for skewness", fontweight = 'bold')

plt.show()

# %% [markdown]
# * **From the above it is observed that target variable is almost normally distributed.**

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
# checking the datatype of the attributes
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
# horsepower is an object, so something must be wrong with the values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# checking for any null values 
data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# car name        False
# dtype: bool

# %%
# checking if 'horsepower' has any missing values
data['horsepower'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Covariance
# * Covariance is a measure of how much two random variables vary together.
#
# * If two variables are independent, their covariance is 0. However, a covariance of 0 does not imply that the variables are independent.
# * (+) : positive relation
# * (-) : negtive relation

# %%
data.cov()
# Out:
#                       mpg    cylinders  displacement         weight  \
# mpg             61.089611   -10.308911   -655.402318   -5505.211745
# cylinders      -10.308911     2.893415    168.623214    1290.695575
# displacement  -655.402318   168.623214  10872.199152   82368.423240
# weight       -5505.211745  1290.695575  82368.423240  717140.990526
# acceleration     9.058930    -2.370842   -156.332976    -974.899011
# model year      16.741163    -2.193499   -142.717137    -959.946344
# origin           3.532185    -0.767477    -50.964989    -394.639330
#
#               acceleration  model year      origin
# mpg               9.058930   16.741163    3.532185
# cylinders        -2.370842   -2.193499   -0.767477
# displacement   -156.332976 -142.717137  -50.964989
# weight         -974.899011 -959.946344 -394.639330
# acceleration      7.604848    2.938105    0.455354
# model year        2.938105   13.672443    0.535790
# origin            0.455354    0.535790    0.643292

# %% [markdown]
# ## Correlation
# * Correlation is a standardized version of covariance.
# * Between -1 and 1
# * Zero = Not correlated
# * (+) : positive relation
# * (-) : negtive relation

# %%
corrmat = data.corr()
corrmat
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
f, ax = plt.subplots(figsize = (14, 11))
sns.heatmap(corrmat, cmap = 'coolwarm', square = True, annot = True);

# %%
corr = data.corr()
corr.style.background_gradient(cmap = 'coolwarm').set_precision(4)

# %%
# Copy dataframe to save progress at this checkpoint
checkpoint1 = data

# %%
# Load this cell instead of starting from beginning
data = checkpoint1

# %% [markdown]
# <a id = "2"></a><br>
# # Data Preprocessing

# %% [markdown]
# We can see that **car names** is obviously an object as it contain strings, but is knowing the name of the car important to the rest of the dataset? Besides being able to compare car features while knowing what the car name and manufactuiring name is, no, so we can drop that column.
#
# If we did keep **car names**, then we would have to seperate and organize the car name and manufacturer.
#
# (Also I just don't want to have to deal with car names and manufacturing names. We can use the backup data if we need to view them)

# %%
# drop car name column
data.drop(['car name'], axis = 1, inplace = True)
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# * **Now we look at horsepower to see what is going on..**

# %%
# list of all unique values in horsepower
data['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %% [markdown]
# * It looks like there are **?** values in horsepower. That is because pandas coerced the entire column as an object when we imported the data set due to **?**. Lets see how many there are and if we should keep or remove them.

# %%
# calculate how many are '?' values in horsepower
data[data['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin
# 32           71       1
# 126          74       1
# 330          80       2
# 336          80       1
# 354          81       2
# 374          82       1

# %% [markdown]
# We can see there are 6 records with **?** values in horsepower
#
# **We have two choices for ? values:**
# 1. Remove those records from the data set
# 2. Replace the **?** values with some central values
#
# First we need to convert those **?** into NaN values

# %%
# replace ? with NaN and convert horsepower from object to float
data['horsepower'] = pd.to_numeric(data['horsepower'], errors = 'coerce')

# %%
# let's print these 6 NaN containing rows 
data[data['horsepower'].isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model year  origin
# 32           71       1
# 126          74       1
# 330          80       2
# 336          80       1
# 354          81       2
# 374          82       1

# %%
# The missing values in horsepower only account for 1.5% of the data, so we could remove them if we wanted to
6 / len(data)
# Out:
# 0.01507537688442211

# %%
# We can double check once replacing ? with NaN that there is 6 missing values
data['horsepower'].isnull().sum()
# Out:
# 6

# %%
data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
# horsepower is now a float
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
data['horsepower'].describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
# Visualizing 'Horsepower' feature for outliers and skewnwss
plt.figure(figsize = ( 15, 4))

plt.subplot(1, 2, 1)
sns.boxplot(x = data['horsepower'])
plt.title("Boxplot for outliers detection", fontweight = 'bold')

plt.subplot(1, 2, 2)
sns.distplot(data['horsepower'])
plt.title("Distribution plot for skewness", fontweight = 'bold')

plt.show()

# %% [markdown]
# * **From the above plots it is observed the `Horsepower` column contains `few outliers` in upper boundary and it is `Right Skewed`**.
# * **So `replacing null values with Median` instead of Mean**.

# %%
# Now we can replace the NaN values with median value from horsepower
data['horsepower'].fillna(data['horsepower'].median(), inplace = True)

# %%
# Now there is no missing data
data["horsepower"].isnull().sum()
# Out:
# 0

# %%
data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.304020  2970.424623
# std      7.815984    1.701004    104.269838   38.222625   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# Copy dataframe to save progress at this checkpoint
checkpoint2 = data

# %%
# Load this cell instead of starting from beginning
data = checkpoint2

# %% [markdown]
# <a id = "2"></a><br>
# # Plotting Data

# %% [markdown]
# * Lets replace the origin column values with their respective true values so we can compare the origin of cars with the other features more easily instead of having to look at the graphs with vertical or horizontal dots

# %%
data['origin'].replace({1:'USA', 2:'Japan', 3:'Europe'}, inplace = True)
data.head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# 13  14.0          8         455.0       225.0    3086          10.0
# 14  24.0          4         113.0        95.0    2372          15.0
# 15  22.0          6         198.0        95.0    2833          15.5
# 16  18.0          6         199.0        97.0    2774          15.5
# 17  21.0          6         200.0        85.0    2587          16.0
# 18  27.0          4          97.0        88.0    2130          14.5
# 19  26.0          4          97.0        46.0    1835          20.5
#
#     model year  origin
# 0           70     USA
# 1           70     USA
# 2           70     USA
# 3           70     USA
# 4           70     USA
# 5           70     USA
# 6           70     USA
# 7           70     USA
# 8           70     USA
# 9           70     USA
# 10          70     USA
# 11          70     USA
# 12          70     USA
# 13          70     USA
# 14          70  Europe
# 15          70     USA
# 16          70     USA
# 17          70     USA
# 18          70  Europe
# 19          70   Japan

# %%
data['origin'].value_counts()
# Out:
# USA       249
# Europe     79
# Japan      70
# Name: origin, dtype: int64

# %%
data['origin'].value_counts(normalize = True)
# Out:
# USA       0.625628
# Europe    0.198492
# Japan     0.175879
# Name: origin, dtype: float64

# %%
# Pie plot for origin
data.groupby('origin').size().plot(kind = 'pie', autopct = '%.2f%%', ylabel = '')
plt.show()

# %% [markdown]
# First let us look at the pairplot between every feature.
#
# * We can see
#     * clinders and origin can be categorical feature
#     * and also explore about correlations between features

# %%
sns.pairplot(data[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration']], diag_kind = 'kde')
plt.show()

# %% [markdown]
# * **From the above plots it is observed that all the pairs of columns have high correlation between them and most of the columns are normally distributed.**

# %%
# heatmap to visualize the pearson's correlation matrix between the numeric variables
plt.figure(figsize = (10, 7))
sns.heatmap(data.corr(), annot = True, cmap = "YlGnBu", mask = np.triu(data.corr(), k = 1))
plt.show()

# %% [markdown]
# **From the above heatmap**
#
# * **Cylinders, Displacement, HorsePower, weight are high negitive correlation with MPG.**
#
# * **Cylinders, Displacement, HorsePower, weight are having high positive correlation between them.**

# %%
# The describe() method shows a summary of the nummerical attributes.
data.describe().T.round(decimals = 2)
# Out:
#                count     mean     std     min      25%     50%      75%  \
# mpg            398.0    23.51    7.82     9.0    17.50    23.0    29.00
# cylinders      398.0     5.45    1.70     3.0     4.00     4.0     8.00
# displacement   398.0   193.43  104.27    68.0   104.25   148.5   262.00
# horsepower     398.0   104.30   38.22    46.0    76.00    93.5   125.00
# weight         398.0  2970.42  846.84  1613.0  2223.75  2803.5  3608.00
# acceleration   398.0    15.57    2.76     8.0    13.82    15.5    17.17
# model year     398.0    76.01    3.70    70.0    73.00    76.0    79.00
# origin_Europe  398.0     0.20    0.40     0.0     0.00     0.0     0.00
# origin_Japan   398.0     0.18    0.38     0.0     0.00     0.0     0.00
# origin_USA     398.0     0.63    0.48     0.0     0.00     1.0     1.00
#
#                   max
# mpg              46.6
# cylinders         8.0
# displacement    455.0
# horsepower      230.0
# weight         5140.0
# acceleration     24.8
# model year       82.0
# origin_Europe     1.0
# origin_Japan      1.0
# origin_USA        1.0

# %%
sns.pairplot(data, hue = 'origin')
plt.show()

# %% [markdown]
# ## Let's take a closer look at some of those graphs

# %%
# Count plot for all discrete features
# Univariate Analysis

discrete_columns_list = ['cylinders', 'model year', 'origin']
plt.figure(figsize = (16, 4))
for i in range(len(discrete_columns_list)):
    plt.subplot(1, 3, i + 1)
    sns.countplot(data[discrete_columns_list[i]], 
                  order = data[discrete_columns_list[i]].value_counts().index,)
    plt.title(discrete_columns_list[i], fontweight = "bold")
    plt.xlabel('')
    plt.ylabel('count', fontsize = 15)

# %% [markdown]
# **From the above visuals:**
#
# * **`Cylinders`: Most of the automobiles contains 4 cylinders.**
#
# * **`Model Year`: The number of cars manufactured in the year 1973.**
#
# * **`Origin`: Most of the automobiles are manufactured in USA.**

# %%
# Multivariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.boxplot(x = data['cylinders'], y = data['mpg'])
plt.axhline(data['mpg'].mean(), color = 'r', linestyle = 'dashed', linewidth = 2)
plt.xlabel('cylinders', fontsize = 15)
plt.ylabel('mpg', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# We can easily visualize that the mileage per gallon (mpg) of 4 cylinder vehicles is maximum and we also saw that most of the vehicles are 4 cylinder.
# - From the above result we can carry out the inference that for most of the people **mileage(mpg)** is one of the major factor while buying a vehicle.

# %%
# Multivariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.stripplot(x = data['cylinders'], y = data['mpg'], jitter = True, size = 4)
plt.xlabel('cylinders', fontsize = 15)
plt.ylabel('mpg', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %%
# Multivariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.boxplot(x = data['model year'], y = data['mpg'])
plt.axhline(data['mpg'].mean(), color = 'r', linestyle = 'dashed', linewidth = 2)
plt.xlabel('model year', fontsize = 15)
plt.ylabel('mpg', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# * With every year and with the newer models of the vehicles mileage per gallon (mpg) also increases.

# %%
# Multivariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.boxplot(x = data['origin'], y = data['horsepower'])
plt.axhline(data['horsepower'].mean(), color = 'r', linestyle = 'dashed', linewidth = 2)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('horsepower', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %%
# Multivariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.boxplot(x = data['origin'], y = data['mpg'])
plt.axhline(data['mpg'].mean(), color = 'r', linestyle = 'dashed', linewidth = 2)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('mpg', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# The red line marks the  average of the set. From the above plot we can observe:
#
#  - Majority of the cars from USA (almost 75%) have MPG below global average.
#  - Majority of the cars from Japan and Europe have MPG above global average.

# %%
# Multivariate Analysis
# Make the strip plot using jitter and a smaller point size
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.stripplot(x = data['cylinders'], y = data['horsepower'], jitter = True, size = 4)
plt.xlabel('cylinders', fontsize = 15)
plt.ylabel('horsepower', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %%
# Univariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.distplot(data['horsepower'])
plt.xlabel('horsepower', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Horsepower rates the engine performance of cars
# 2. From the above plot we can see the distribution of the horsepower of the vehicles.
# 3. We can visualize that most of the vehicles have around **75-110 horsepower** and only few vehicles have horsepoer above 200.

# %%
print("Skewness: %f" % data['horsepower'].skew())
print("Kurtosis: %f" % data['horsepower'].kurt())
# Out:
# Skewness: 1.106224
# Kurtosis: 0.763583

# %% [markdown]
# **Engine displacement** is the swept volume of all the pistons inside the cylinders of a reciprocating engine in a single movement from top dead centre (TDC) to bottom dead centre (BDC).

# %%
# Univariate Analysis
fig, axes = plt.subplots(1, 1, figsize = (10, 7),)
sns.distplot(data['displacement'])
plt.xlabel('displacement', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(True)
plt.show()

# %%
# Exploring the range and distribution of numerical Variables 
# Plotting box plot to check the outliers

fig, ax = plt.subplots(6, 2, figsize = (15, 13))
sns.boxplot(x = data["mpg"], ax = ax[0,0])
sns.distplot(data['mpg'], ax = ax[0,1])

sns.boxplot(x = data["cylinders"], ax = ax[1,0])
sns.distplot(data['cylinders'], ax = ax[1,1])

sns.boxplot(x = data["displacement"], ax = ax[2,0])
sns.distplot(data['displacement'], ax = ax[2,1])

sns.boxplot(x = data["horsepower"], ax = ax[3,0])
sns.distplot(data['horsepower'], ax = ax[3,1])

sns.boxplot(x = data["weight"], ax = ax[4,0])
sns.distplot(data['weight'], ax = ax[4,1])

sns.boxplot(x = data["acceleration"], ax = ax[5,0])
sns.distplot(data['acceleration'], ax = ax[5,1])

plt.tight_layout()

# %% [markdown]
# * **There are very few ouliers present in the dataset which are very nearer to upper boundary. So, there is no need of outliers treatment.**

# %%
# Plot a linear regression between 'weight' and 'horsepower'
sns.lmplot(x = 'weight', y = 'horsepower', data = data)
plt.grid(True)
plt.show()

# %% [markdown]
# When there is a more complex relationship between two variables, a simple first order regression is often not sufficient to accurately capture the relationship between them. Seaborn makes it easy to compute and visualize regressions of higher orders. The function sns.regplot() will do the job.
#
# Now, let's look at the variables 'weight' and 'mpg'. This time we will need to show the data points in a scatter plot first, and then use the argument scatter=None in the sns.regplot() function to prevent plotting the scatter points again.

# %%
plt.scatter(data['weight'], data['mpg'], label = 'data', color = 'magenta', marker = '.')

sns.regplot(x = 'weight', y = 'mpg', data = data, scatter = None, label = '1st order', color = 'black') # order = 1 by default

sns.regplot(x = 'weight', y = 'mpg', data = data, scatter = None, label = '2nd order', color = 'green', order = 2)

plt.legend(loc = 'upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Weight vs. Horsepower

# %% [markdown]
# Let's re-plot the 'weight' and 'horsepower' data by origin, i.e. region/country of manufacturing using group Linear Regressions

# %%
# Plot a linear regression between 'weight' and 'horsepower', with a hue of 'origin' and palette of 'Set1'
sns.lmplot(x = 'weight', y = 'horsepower', data = data, hue = 'origin', palette = 'Set1', markers = [".", ".", "."])
plt.grid(True)
plt.show()

# %% [markdown]
# **USA automobiles seem to have higher horsepower at a given weight**

# %% [markdown]
# We can also group the linear regressions by row or column instead of overlaying them in the same plot by passing the argument row = 'categorical variable' or col = 'categorical variable'.

# %%
# Plot linear regressions between 'weight' and 'horsepower' grouped row-wise by 'origin'
sns.lmplot(x = 'weight', y = 'horsepower', col = 'origin', data = data)
plt.show()

# %% [markdown]
# ## Horsepower vs. mpg

# %%
sns.lmplot(x = 'horsepower', y = 'mpg', data = data, hue = 'origin', palette = 'Set1', markers = [".", ".", "."])
plt.grid(True)
plt.show()

# %%
sns.lmplot(x = 'horsepower', y = 'mpg', col = 'origin', data = data)
plt.show()

# %% [markdown]
# ## Displacement vs. mpg

# %%
sns.lmplot(x = 'displacement', y = 'mpg', data = data, hue = 'origin', palette = 'Set1', markers = [".", ".", "."])
plt.grid(True)
plt.show()

# %%
sns.lmplot(x = 'displacement', y = 'mpg', col = 'origin', data = data)
plt.show()

# %% [markdown]
# ## Weight vs. mpg

# %%
sns.lmplot(x = 'weight', y = 'mpg', data = data, hue = 'origin', palette = 'Set1', markers = [".", ".", "."])
plt.grid(True)
plt.show()

# %%
sns.lmplot(x = 'weight', y = 'mpg', col = 'origin', data = data)
plt.show()

# %% [markdown]
# ## Acceleration vs. mpg

# %%
sns.lmplot(x = 'acceleration', y = 'mpg', data = data, hue = 'origin', palette = 'Set1', markers = [".", ".", "."])
plt.grid(True)
plt.show()

# %%
sns.lmplot(x = 'acceleration', y = 'mpg', col = 'origin', data = data)
plt.show()

# %%
# Copy dataframe to save progress at this checkpoint
checkpoint3 = data

# %%
# Load this cell instead of starting from beginning
data = checkpoint3

# %% [markdown]
# We cannot use feature 'origin' as is, because the values are numerical but categorical(biased), so we need to create dummy variables.
#
# I will be applying One Hot Encoding for **origin** and **cylinders** because these features have categorical values.

# %%
data = pd.get_dummies(data, columns = ['origin'])
data.head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# 13  14.0          8         455.0       225.0    3086          10.0
# 14  24.0          4         113.0        95.0    2372          15.0
# 15  22.0          6         198.0        95.0    2833          15.5
# 16  18.0          6         199.0        97.0    2774          15.5
# 17  21.0          6         200.0        85.0    2587          16.0
# 18  27.0          4          97.0        88.0    2130          14.5
# 19  26.0          4          97.0        46.0    1835          20.5
#
#     model year  origin_Europe  origin_Japan  origin_USA
# 0           70              0             0           1
# 1           70              0             0           1
# 2           70              0             0           1
# 3           70              0             0           1
# 4           70              0             0           1
# 5           70              0             0           1
# 6           70              0             0           1
# 7           70              0             0           1
# 8           70              0             0           1
# 9           70              0             0           1
# 10          70              0             0           1
# 11          70              0             0           1
# 12          70              0             0           1
# 13          70              0             0           1
# 14          70              1             0           0
# 15          70              0             0           1
# 16          70              0             0           1
# 17          70              0             0           1
# 18          70              1             0           0
# 19          70              0             1           0

# %%
data['cylinder'] = data['cylinder'.astype('float')

# %%
data.dtypes
# Out:
# mpg              float64
# cylinders          int64
# displacement     float64
# horsepower       float64
# weight             int64
# acceleration     float64
# model year         int64
# origin_Europe      uint8
# origin_Japan       uint8
# origin_USA         uint8
# dtype: object

# %% [markdown]
# <a id = "2"></a><br>
# # Train Test Split & Standardization

# %%
# Converting data into dependent and independent variable 

# X is our feature data
# y is our target variable

X = data.drop(['mpg'], axis = 1)
y = data['mpg']

print("Shape of X :", X.shape)
print('Shape of y :', y.shape)
# Out:
# Shape of X : (398, 9)
# Shape of y : (398,)

# %%
# Applying z-score normalization on dataset
column_names = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year']

sc = StandardScaler()

for col in column_names:
    X[col] = sc.fit_transform(X[col].values.reshape(-1,1))
X.head()
# Out:
#    cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0   1.498191      1.090604    0.673118  0.630870     -1.295498   -1.627426
# 1   1.498191      1.503514    1.589958  0.854333     -1.477038   -1.627426
# 2   1.498191      1.196232    1.197027  0.550470     -1.658577   -1.627426
# 3   1.498191      1.061796    1.197027  0.546923     -1.295498   -1.627426
# 4   1.498191      1.042591    0.935072  0.565841     -1.840117   -1.627426
#
#    origin_Europe  origin_Japan  origin_USA
# 0              0             0           1
# 1              0             0           1
# 2              0             0           1
# 3              0             0           1
# 4              0             0           1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

print("Shape of x_train : ", X_train.shape)
print("Shape of y_train : ", y_train.shape)

print("\nShape of x_test : ", X_test.shape)
print("Shape of y_test : ", y_test.shape)
# Out:
# Shape of x_train :  (318, 9)
# Shape of y_train :  (318,)
#
# Shape of x_test :  (80, 9)
# Shape of y_test :  (80,)

# %%
# Copy dataframe to temp to be able to go to this checkpoint
temp = data

# %%
# Load this cell instead of starting from beginning
data = temp

# %% [markdown]
# <a id = "2"></a><br>
# # Linear Regression

# %%
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X_test)
print("Linear Regression intercept:", LR.intercept_)
# Out:
# Linear Regression Coef: 24.31857737313241

# %%
mse = mean_squared_error(y_test, y_pred)
print("Linear Regression MSE: ", mse)
# Out:
# Linear Regression MSE:  8.810666699729982

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8425175498812941

# %%
print('Accuracy of Linear Regression on test set: {:.4f}'.format(LR.score(X_test, y_test)))
# Out:
# Accuracy of Linear Regression on test set: 0.8425

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Support Vector Regressor

# %%
SVM = SVR(kernel = 'linear', C = 1.0)
SVM.fit(X_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = SVM.predict(X_test)
print("Support Vecor Regressor intercept:", SVM.intercept_)
# Out:
# SVR Coef: [24.13745367]

# %%
mse = mean_squared_error(y_test, y_pred)
print("Support Vector Regression MSE: ", mse)
# Out:
# Support Vector Regression MSE:  9.407172662916945

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8318555621118577

# %%
print('Accuracy of Support Vector Regression on test set: {:.4f}'.format(SVM.score(X_test, y_test)))
# Out:
# Accuracy of Support Vector Regression on test set: 0.8319

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Random Forest Regressor

# %%
RFG = RandomForestRegressor(criterion = 'mse', n_estimators = 50, random_state = 0)
RFG.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
y_pred = RFG.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Random Forest Regression MSE: ", mse)
# Out:
# Random Forest Regression MSE:  5.847315200000002

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8954846942126897

# %%
print('Accuracy of Random Forest Regressor on test set: {:.4f}'.format(RFG.score(X_test, y_test)))
# Out:
# Accuracy of Random Forest Regressor on test set: 0.8955

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Decision Tree Regressor

# %%
DTR = DecisionTreeRegressor(criterion = 'friedman_mse', splitter = 'random', random_state = 0)
DTR.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', random_state=0,
#                       splitter='random')

# %%
y_pred = DTR.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Decision Tree Regression MSE: ", mse)
# Out:
# Decision Tree Regression MSE:  7.5798749999999995

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8645168036341554

# %%
print('Accuracy of Decision Tree Regressor on test set: {:.4f}'.format(DTR.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree Regressor on test set: 0.8645

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Ridge Regression

# %%
RR = Ridge(alpha = 1, random_state = 0)
RR.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, random_state=0)

# %%
y_pred = RR.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Ridge Regression MSE: ", mse)
# Out:
# Ridge Regression MSE:  8.818551795598268

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8423766111465675

# %%
print('Accuracy of Ridge Regression on test set: {:.4f}'.format(RR.score(X_test, y_test)))
# Out:
# Accuracy of Ridge Regression on test set: 0.8424

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Lasso Regressor

# %%
L_R = Ridge(alpha = 1, random_state = 0)
L_R.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, random_state=0)

# %%
y_pred = L_R.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Ridge Regression MSE: ", mse)
# Out:
# Ridge Regression MSE:  8.818551795598268

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8423766111465675

# %%
print('Accuracy of Lasso Regression on test set: {:.4f}'.format(L_R.score(X_test, y_test)))
# Out:
# Accuracy of Lasso Regression on test set: 0.8424

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # ElasticNet Regressor

# %%
ENR = Ridge(alpha = 1, random_state = 0)
ENR.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, random_state=0)

# %%
y_pred = ENR.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("ElasticNet Regression MSE: ", mse)
# Out:
# ElasticNet Regression MSE:  8.818551795598268

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8423766111465675

# %%
print('Accuracy of ElasticNet Regression on test set: {:.4f}'.format(ENR.score(X_test, y_test)))
# Out:
# Accuracy of ElasticNet Regression on test set: 0.8424

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # KNeighbors Regressor

# %%
KNR = KNeighborsRegressor(n_neighbors = 3, algorithm = 'auto')
KNR.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred = KNR.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("KNeighbors Regression MSE: ", mse)
# Out:
# KNeighbors Regression MSE:  7.4627222222222205

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8666108002761146

# %%
print('Accuracy of KNeighbors Regression on test set: {:.4f}'.format(KNR.score(X_test, y_test)))
# Out:
# Accuracy of KNeighbors Regression on test set: 0.8666

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Gradient Boosting Regressor

# %%
GBR = GradientBoostingRegressor(n_estimators = 4000, loss = 'ls', criterion = 'friedman_mse', random_state = 0)
GBR.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=4000, random_state=0)

# %%
y_pred = GBR.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Gradient Boosting Regression MSE: ", mse)
# Out:
# Gradient Boosting Regression MSE:  5.233537357163882

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.9064554007224898

# %%
print('Accuracy of ElasticNet Regression on test set: {:.4f}'.format(GBR.score(X_test, y_test)))
# Out:
# Accuracy of ElasticNet Regression on test set: 0.9065

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.grid(True)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Artificial Neurel Network

# %% [markdown]
# ## Build the NN model with adequate number of hidden layers, appropriate optimizer and loss functions.
# * **Building a Sequential model with two densely connected hidden layers, and an output layer that return a single, continuous value.**

# %%
def build_model():
    model = keras.Sequential([
                            layers.Dense(64, activation = 'relu', input_shape = [len(X.keys())]),
                            layers.Dense(64, activation = 'relu'),
                            layers.Dense(1)
  ])
  
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.001) # default learning rate is 0.001
  
    model.compile(loss = 'mse',
                optimizer = optimizer,
                metrics = ['mae', 'mse', 'mape'])
    return model

model = build_model()

# %% [markdown]
# ## Display the model summary

# %%
model.summary()

# %% [markdown]
# ## Fit the model by taking validation data as 20% of training data.

# %%
# Display the training progress by printing a single dot for each complted epoch
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs):
        if epoch%500 == 0:print('')
        if epoch%5 == 0:print('.',end='')
EPOCHS = 1000
history = model.fit(X_train, y_train,
                  epochs = EPOCHS, validation_split = 0.2,
                  verbose = 0, callbacks = [PrintDot()]) #calculate print dot

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()

# %% [markdown]
# ## Plot the graph of Number of epochs vs/ training and validation loss

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error[MPG]') 
    plt.plot(hist['epoch'], hist['mae'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'], label='Validation Error')
    plt.ylim([0,5])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error[$MPG^2$]')
    plt.plot(hist['epoch'], hist['mse'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'], label='Val Error')
    plt.ylim([0,20])
    plt.legend()
    plt.show()  
plot_history(history)

# %% [markdown]
# * **From the above plot we can say that model is overfitting, so we need to perform early stopping which is used to avoid overfitting problem.**

# %%
# Applying early stopping method to avoid overfitting
model = build_model()

# The patience is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10)

history = model.fit(X_train, y_train,
                    epochs = EPOCHS, validation_split = 0.2, 
                    verbose = 0, callbacks = [early_stop, PrintDot()])

# %% [markdown]
# * **Let's re-plot the history to hopefully see the model training stopped before things get worse for the validation data.**

# %%
plot_history(history)

# %% [markdown]
# * **From the above plot it is observed that model training stopped after 80 epochs with a less mean absolute error as around 2.**

# %% [markdown]
# ## Evaluate the model and predict it on testing data

# %%
# Evaluating the model
mse = model.evaluate(X_test, y_test, verbose = 0)
print('Testing set Mean Abs Error:', mse)

# %%
# Predicting the model
test_predictions = model.predict(X_test).flatten()
train_predictions = model.predict(X_train).flatten()

# %% [markdown]
# ## Plot between actual values v/s predicted values (regression line and scatter plot)

# %%
plt.scatter(y_test,test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0, plt.xlim()[1]])
plt.ylim([0, plt.ylim()[1]])
plt.plot([-100,100], [-100,100], color = 'red')
plt.show()

# %%
# calculating the mean-squared error, mean absolute error, and the R-Squared error on traing and testing.

mse = mean_squared_error(y_test, test_predictions)
print('MSE is' ,mse)

mae = mean_absolute_error(y_test, test_predictions)
print('MAE is', mae)

rsq = r2_score(y_train, train_predictions)
print('R-square,Training is', rsq)

rsq = r2_score(y_test, test_predictions)
print('R-square,Testing is',rsq)

# %%
# Initialising the ANN
model = Sequential()

# %%
# Adding the input layer and the first hidden layer
model.add(Dense(50, activation = 'relu', input_dim = X.shape[1]))

# %%
# Adding the second hidden layer
model.add(Dense(25, activation = 'relu'))

# Adding the third hidden layer
model.add(Dense(50, activation = 'relu'))

# %%
# Adding the output layer
model.add(Dense(1))

# %%
# Compiling the ANN
model.compile(loss = 'mean_squared_error', optimizer = 'Adamax')

#create monitor
monitor = EarlyStopping(monitor = 'val_loss', min_delta = 1e-3, patience = 5, verbose = 1, mode = "auto")

# Fitting the ANN to the Training set
model_history = model.fit(X, y, callbacks = [monitor], validation_split = 0.20, batch_size = 10, nb_epoch = 1000)

# %%
model_history.summary()

# %%
# Predict the Test set results
# Threshold of predicted probability = 0.5
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)

# %%
# P3.3.1 Make the Confusion Matrix and show the result
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test , y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")

# %%
model_history.params

# %%
pd.DataFrame(model_history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# accuracy
plt.plot(model_history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['Train'], loc = 'lower right')
plt.show()

# Loss
plt.plot(model_history.history['loss'])
plt.title('Model Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['Train'], loc = 'upper right')
plt.show()

# %%
ann_pred = model.predict(X_test)
score = rmse(y_test, ann_pred)

# %%
score

# %%
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss',min_delta=0, patience=15, verbose=0, mode='auto')
model.fit(X_train,Y_train, validation_data=(X_test,Y_test), callbacks=[monitor], epochs=3000, verbose=2)
