# %%
# Our objective is to predict the MPG, so MPG is our target variable.
# We have to check which independent vatiable has a linear relationship with MPG
# For that, we are using the 4 value or pearon ceofficient

# If pearson coefficient is 0.7 in magnitude or greater than this we are considering 
    # there is linear relationship between independent variable and target variable
    
# If pearson coefficient is less than 0.7 in magnitude than we are considering there 
    # is no good linear relationship between independent variable and target variable
    
# So calculate pearson coefficient for each independent variable with target variable

print("the r value and p value for cylinders and mpg respectively is {}".format(stats.pearsonr(data['cylinders'], data['mpg'])))
# Out:
# the r value and p value for cylinders and mpg respectively is (-0.7753962854205543, 4.503992246176927e-81)

# %%
for i in data.columns:
    if i != 'car name':
        print("the r and p value for "+i+" and mpg respectively is {}".format(stats.pearsonr(data[i], data['mpg'])))
# Out:
# the r and p value for mpg and mpg respectively is (0.9999999999999998, 0.0)
# the r and p value for cylinders and mpg respectively is (-0.7753962854205543, 4.503992246176927e-81)
# the r and p value for displacement and mpg respectively is (-0.804202824805898, 1.655888910192639e-91)
# the r and p value for horsepower and mpg respectively is (-0.7714371350025524, 9.255477533169094e-80)
# the r and p value for weight and mpg respectively is (-0.831740933244335, 2.9727995640500577e-103)
# the r and p value for acceleration and mpg respectively is (0.42028891210165065, 1.823091535078553e-18)
# the r and p value for model year and mpg respectively is (0.5792671330833096, 4.844935813365483e-37)
# the r and p value for origin and mpg respectively is (0.5634503597738432, 1.0114822102335907e-34)

# %% [markdown]
# **As we can see, cylinders, displacement, horsepower, and weight have linear relationships with MPG because the r value is greater than 0.7, while acceleration, model, and origin have an r value of less than 0.7.**
#
# **We can ignore these 3 columns because they are not very good in predicting MPG as we are using a linear regression model**

# %%
# multivariate plot
sns.pairplot(data = data)
plt.show()

# %%
# check which number of cylinders are used the most
plt.figure(figsize = (7, 7))
sns.countplot(data['cylinders'], data = data)
plt.show()
# Out:
# /Users/ryanbalachandran/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **4 cylinder cars are the most popular**

# %%
# display most cars are of which model
plt.figure(figsize = (7, 7))
sns.countplot(data['model year'])
plt.show()
# Out:
# /Users/ryanbalachandran/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Most cars are of 73 model**

# %%
plt.figure(figsize = (7, 7))
sns.jointplot(data['model year'], data['mpg'])
plt.show()
# Out:
# /Users/ryanbalachandran/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X = data.iloc[:,1:8].values
Y = data.iloc[:,0].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test)
print(regressor.score(X_test, Y_test))
# Out:
# 0.816648677639231

# %%
# Dropping the categorical feature from the dataframe for further analysis
data.drop(['car name'], axis = 1, inplace = True)
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# There are ? (missing values) in the horsepower dataset
data['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %% [markdown]
# When we print out all the unique values in horsepower, we find that there is '?' which was used as a placeholder for missing values. Lest remove these entries.

# %%
# Remove the missing values
data = data[data.horsepower != '?']

# %%
# Checking for null values after dropping the rows
'?' in data
# Out:
# False

# %%
# There are 6 less rows than what we started with
# After dropping the rows containing horsepower as '?', now we are left with 392 rows.
print('The dataset contains {0} rows and {1} columns.'.format(data.shape[0], data.shape[1]))
# Out:
# The dataset contains 392 rows and 8 columns.

# %% [markdown]
# Here , I am checking the correlation of all the features of the dataset w.r.t miles-per-gallon i.e. **'mpg'** and arranging the values in ascending order.

# %%
data.corr()['mpg'].sort_values()
# Out:
# weight         -0.832244
# displacement   -0.805127
# cylinders      -0.777618
# acceleration    0.423329
# origin          0.565209
# model year      0.580541
# mpg             1.000000
# Name: mpg, dtype: float64
