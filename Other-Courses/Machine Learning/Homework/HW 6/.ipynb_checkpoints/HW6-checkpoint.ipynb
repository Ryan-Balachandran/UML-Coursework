# %% [markdown]
# # COMP4220: Machine Learning, Fall 2020
#
# # Assignment 6
#
# # Due: Monday, Dec 7th, 10:00PM
#
# Please submit one pdf file for all questions.
#
# ****When turning in assignments after the due date, please clearly specify the number of late hours used.

# %% [markdown]
# # P1. List five hyperparameters you can tweak in a basic neural network?

# %% [markdown]
# 1. Number of Hidden Layers and units
# 2. Dropout
# 3. Network Weight Initialization
# 4. Activation function
# 5. Learning Rate

# %% [markdown]
# # P2. What is backpropagation and how does it work?

# %% [markdown]
# Back-propagation is the essence of neural net training. It is the practice of fine-tuning the weights of a neural net based on the error rate (i.e. loss) obtained in the previous epoch (i.e. iteration). Proper tuning of the weights ensures lower error rates, making the model reliable by increasing its generalization.
#
#
# Back-propagation computes the gradient of the loss function with respect to the weights of the network for a single input–output example, and does so efficiently, unlike a naive direct computation of the gradient with respect to each weight individually. This efficiency makes it feasible to use gradient methods for training multilayer networks, updating weights to minimize loss; gradient descent, or variants such as stochastic gradient descent, are commonly used. The backpropagation algorithm works by computing the gradient of the loss function with respect to each weight by the chain rule, computing the gradient one layer at a time, iterating backward from the last layer to avoid redundant calculations of intermediate terms in the chain rule.

# %% [markdown]
# # P3. Programming Assignment (Artificial Neural Network-ANN)
# The problem of classifying customers staying in the bank or leaving! Please download the Churn_Modelling dataset along with this homework!

# %% [markdown]
# # Part 1 - Data Preprocessing

# %%
# Importing the libraries
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf

# %matplotlib inline

# to make this notebook's output stable across runs
np.random.seed(42)

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
# Import the dataset
dataset = pd.read_csv('Churn_Modelling.csv', delimiter = ',')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
# Check variable data types
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Get unique count for each variable
dataset.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# P3.1.1 Git rid of useless columns # strat from "CreditScore" column

X = dataset.iloc[:, 3:13].values

# P3.1.2 The last column "Exited" is our dependent variable
y = dataset.iloc[:, 13].values

print(X[:10,:], '\n')
print(y[:10])
# Out:
# [[619 'France' 'Female' 42 2 0.0 1 1 1 101348.88]
#  [608 'Spain' 'Female' 41 1 83807.86 1 0 1 112542.58]
#  [502 'France' 'Female' 42 8 159660.8 3 1 0 113931.57]
#  [699 'France' 'Female' 39 1 0.0 2 0 0 93826.63]
#  [850 'Spain' 'Female' 43 2 125510.82 1 1 1 79084.1]
#  [645 'Spain' 'Male' 44 8 113755.78 2 1 0 149756.71]
#  [822 'France' 'Male' 50 7 0.0 2 1 1 10062.8]
#  [376 'Germany' 'Female' 29 4 115046.74 4 1 0 119346.88]
#  [501 'France' 'Male' 44 4 142051.07 2 0 1 74940.5]
#  [684 'France' 'Male' 27 2 134603.88 1 1 1 71725.73]]
#
# [1 0 1 0 0 1 0 1 0 0]

# %%
# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Geography
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])

# Gender
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

# Giving ordinal feature to our variables
geography = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [1])], remainder = 'passthrough')
X = np.array(geography.fit_transform(X))
X = X[:, 1:]

print(X[:10,:], '\n')
print(y[:10])
# Out:
# [[0.0 0.0 619 0 42 2 0.0 1 1 1 101348.88]
#  [0.0 1.0 608 0 41 1 83807.86 1 0 1 112542.58]
#  [0.0 0.0 502 0 42 8 159660.8 3 1 0 113931.57]
#  [0.0 0.0 699 0 39 1 0.0 2 0 0 93826.63]
#  [0.0 1.0 850 0 43 2 125510.82 1 1 1 79084.1]
#  [0.0 1.0 645 1 44 8 113755.78 2 1 0 149756.71]
#  [0.0 0.0 822 1 50 7 0.0 2 1 1 10062.8]
#  [1.0 0.0 376 0 29 4 115046.74 4 1 0 119346.88]
#  [0.0 0.0 501 1 44 4 142051.07 2 0 1 74940.5]
#  [0.0 0.0 684 1 27 2 134603.88 1 1 1 71725.73]]
#
# [1 0 1 0 0 1 0 1 0 0]

# %%
# P3.1.3 Split the dataset into the Training set and Test set (test_size = 0.2)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_test
# Out:
# array([[1.0, 0.0, 597, ..., 1, 1, 192852.67],
#        [0.0, 0.0, 523, ..., 1, 0, 128702.1],
#        [0.0, 1.0, 706, ..., 1, 1, 75732.25],
#        ...,
#        [0.0, 1.0, 578, ..., 1, 0, 141533.19],
#        [1.0, 0.0, 650, ..., 1, 1, 11276.48],
#        [1.0, 0.0, 573, ..., 1, 0, 192950.6]], dtype=object)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (8000, 11)
# (2000, 11)
# (8000,)
# (2000, 11)

# %%
# P3.1.4 Apply Feature Scaling to all features before training a neural network
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Part 2 - Now let's make the ANN!

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = tf.keras.models.Sequential()

# %%
# P3.2.1 Add the input layer and the first hidden layer using 
# (units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11)

classifier.add(tf.keras.layers.Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# %%
# P3.2.2 Add the second hidden layer
# (units = 6, kernel_initializer = 'uniform', activation = 'relu')

classifier.add(tf.keras.layers.Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# %%
#P3.2.3 Add the output layer
# (units = 1, kernel_initializer = 'uniform', activation = 'sigmoid')

classifier.add(tf.keras.layers.Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# P3.2.4 Compile the ANN
# (optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# P3.2.5 Train the ANN to the Training set using (batch_size = 10, epochs = 100)
model_history = classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Train on 8000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 1s 184us/sample - loss: 0.4880 - accuracy: 0.7959
# Epoch 2/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.4281 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 110us/sample - loss: 0.4221 - accuracy: 0.8076
# Epoch 4/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4161 - accuracy: 0.8271
# Epoch 5/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4115 - accuracy: 0.8307
# Epoch 6/100
# 8000/8000 [==============================] - 1s 110us/sample - loss: 0.4082 - accuracy: 0.8341
# Epoch 7/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4056 - accuracy: 0.8341
# Epoch 8/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4040 - accuracy: 0.8336
# Epoch 9/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4019 - accuracy: 0.8346
# Epoch 10/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4015 - accuracy: 0.8346
# Epoch 11/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4004 - accuracy: 0.8354
# Epoch 12/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3996 - accuracy: 0.8338
# Epoch 13/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3992 - accuracy: 0.8359
# Epoch 14/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3984 - accuracy: 0.8342
# Epoch 15/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3978 - accuracy: 0.8360
# Epoch 16/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3970 - accuracy: 0.8366
# Epoch 17/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3972 - accuracy: 0.8356
# Epoch 18/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3967 - accuracy: 0.8371
# Epoch 19/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3964 - accuracy: 0.8363
# Epoch 20/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3959 - accuracy: 0.8367
# Epoch 21/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3953 - accuracy: 0.8350
# Epoch 22/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3954 - accuracy: 0.8361
# Epoch 23/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3958 - accuracy: 0.8356
# Epoch 24/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3946 - accuracy: 0.8370
# Epoch 25/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3943 - accuracy: 0.8374
# Epoch 26/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3946 - accuracy: 0.8366
# Epoch 27/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3946 - accuracy: 0.8364
# Epoch 28/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3937 - accuracy: 0.8371
# Epoch 29/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3931 - accuracy: 0.8372
# Epoch 30/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3929 - accuracy: 0.8370
# Epoch 31/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3919 - accuracy: 0.8371
# Epoch 32/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3910 - accuracy: 0.8374
# Epoch 33/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3896 - accuracy: 0.8390
# Epoch 34/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.3873 - accuracy: 0.8371
# Epoch 35/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.3845 - accuracy: 0.8404
# Epoch 36/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.3817 - accuracy: 0.8395
# Epoch 37/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.3795 - accuracy: 0.8386
# Epoch 38/100
# 8000/8000 [==============================] - 1s 158us/sample - loss: 0.3779 - accuracy: 0.8389
# Epoch 39/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.3770 - accuracy: 0.8406
# Epoch 40/100
# 8000/8000 [==============================] - 1s 149us/sample - loss: 0.3764 - accuracy: 0.8410
# Epoch 41/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.3751 - accuracy: 0.8405
# Epoch 42/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3743 - accuracy: 0.8381
# Epoch 43/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3744 - accuracy: 0.8379
# Epoch 44/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3734 - accuracy: 0.8415
# Epoch 45/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3728 - accuracy: 0.8405
# Epoch 46/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3727 - accuracy: 0.8404
# Epoch 47/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3725 - accuracy: 0.8388
# Epoch 48/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.3721 - accuracy: 0.8394
# Epoch 49/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3720 - accuracy: 0.8407
# Epoch 50/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3721 - accuracy: 0.8416
# Epoch 51/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.3719 - accuracy: 0.8418
# Epoch 52/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.3715 - accuracy: 0.8388
# Epoch 53/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3709 - accuracy: 0.8397
# Epoch 54/100
# 8000/8000 [==============================] - 1s 181us/sample - loss: 0.3710 - accuracy: 0.8424
# Epoch 55/100
# 8000/8000 [==============================] - 1s 139us/sample - loss: 0.3710 - accuracy: 0.8418
# Epoch 56/100
# 8000/8000 [==============================] - 1s 157us/sample - loss: 0.3710 - accuracy: 0.8411
# Epoch 57/100
# 8000/8000 [==============================] - 1s 167us/sample - loss: 0.3697 - accuracy: 0.8424
# Epoch 58/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.3698 - accuracy: 0.8428
# Epoch 59/100
# 8000/8000 [==============================] - 2s 190us/sample - loss: 0.3702 - accuracy: 0.8419
# Epoch 60/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.3702 - accuracy: 0.8414
# Epoch 61/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.3697 - accuracy: 0.8425
# Epoch 62/100
# 8000/8000 [==============================] - 1s 175us/sample - loss: 0.3703 - accuracy: 0.8428
# Epoch 63/100
# 8000/8000 [==============================] - 1s 133us/sample - loss: 0.3688 - accuracy: 0.8413
# Epoch 64/100
# 8000/8000 [==============================] - 2s 192us/sample - loss: 0.3699 - accuracy: 0.8416
# Epoch 65/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3690 - accuracy: 0.8434
# Epoch 66/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3690 - accuracy: 0.8410
# Epoch 67/100
# 8000/8000 [==============================] - 1s 147us/sample - loss: 0.3691 - accuracy: 0.8432
# Epoch 68/100
# 8000/8000 [==============================] - 2s 214us/sample - loss: 0.3687 - accuracy: 0.8422
# Epoch 69/100
# 8000/8000 [==============================] - 1s 130us/sample - loss: 0.3685 - accuracy: 0.8416
# Epoch 70/100
# 8000/8000 [==============================] - 2s 196us/sample - loss: 0.3689 - accuracy: 0.8416
# Epoch 71/100
# 8000/8000 [==============================] - 1s 170us/sample - loss: 0.3681 - accuracy: 0.8438
# Epoch 72/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3683 - accuracy: 0.8415
# Epoch 73/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3678 - accuracy: 0.8428
# Epoch 74/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3681 - accuracy: 0.8425
# Epoch 75/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3678 - accuracy: 0.8438
# Epoch 76/100
# 8000/8000 [==============================] - 2s 208us/sample - loss: 0.3683 - accuracy: 0.8446
# Epoch 77/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.3677 - accuracy: 0.8434
# Epoch 78/100
# 8000/8000 [==============================] - 1s 110us/sample - loss: 0.3679 - accuracy: 0.8429
# Epoch 79/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3676 - accuracy: 0.8436
# Epoch 80/100
# 8000/8000 [==============================] - 1s 180us/sample - loss: 0.3674 - accuracy: 0.8435
# Epoch 81/100
# 8000/8000 [==============================] - 1s 150us/sample - loss: 0.3676 - accuracy: 0.8434
# Epoch 82/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.3672 - accuracy: 0.8425
# Epoch 83/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.3665 - accuracy: 0.8460
# Epoch 84/100
# 8000/8000 [==============================] - 1s 177us/sample - loss: 0.3670 - accuracy: 0.8429
# Epoch 85/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3669 - accuracy: 0.8453
# Epoch 86/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3671 - accuracy: 0.8440
# Epoch 87/100
# 8000/8000 [==============================] - 1s 171us/sample - loss: 0.3666 - accuracy: 0.8432
# Epoch 88/100
# 8000/8000 [==============================] - 2s 200us/sample - loss: 0.3656 - accuracy: 0.8441
# Epoch 89/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.3661 - accuracy: 0.8445
# Epoch 90/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.3665 - accuracy: 0.8443
# Epoch 91/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.3665 - accuracy: 0.8440
# Epoch 92/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.3664 - accuracy: 0.8454
# Epoch 93/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3662 - accuracy: 0.8445
# Epoch 94/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.3661 - accuracy: 0.8446
# Epoch 95/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.3661 - accuracy: 0.8436
# Epoch 96/100
# 8000/8000 [==============================] - 1s 183us/sample - loss: 0.3656 - accuracy: 0.8451
# Epoch 97/100
# 8000/8000 [==============================] - 1s 150us/sample - loss: 0.3663 - accuracy: 0.8451 - loss: 0
# Epoch 98/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.3654 - accuracy: 0.8449
# Epoch 99/100
# 8000/8000 [==============================] - 1s 132us/sample - loss: 0.3654 - accuracy: 0.8461
# Epoch 100/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.3655 - accuracy: 0.8464

# %% [markdown]
# # Part 3 - Making the predictions and evaluating the model

# %%
# Predict the Test set results
# Treshold of predicted probability = 0.5
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
# P3.3.1 Make the Confusion Matrix and show the result
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test , y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[1532   63]
#  [ 254  151]]
# Accuracy: 84.15%

# %%
model_history.params
# Out:
# {'batch_size': 10,
#  'epochs': 100,
#  'steps': 800,
#  'samples': 8000,
#  'verbose': 1,
#  'do_validation': False,
#  'metrics': ['loss', 'accuracy']}

# %%
pd.DataFrame(model_history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# accuracy
plt.plot(model_history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['Train'], loc = 'lower right')
plt.show()

# Loss
plt.plot(model_history.history['loss'])
plt.title('Model Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['Train'], loc = 'upper right')
plt.show()

# %% [markdown]
# # P4. Train a deep MLP on the MNIST dataset (you can load it using keras.datasets.mnist.load_data(). See if you can get over 98% precision. Try searching for the optimal learning rate by using the approach presented in chapter 10 (i.e., by growing the learning rate exponentially, plotting the loss, and finding the point where the loss shoots up). Try adding all the bells and whistles—save checkpoints, use early stopping, and plot learning curves using TensorBoard.

# %%
# Importing the libraries
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline

# to make this notebook's output stable across runs
np.random.seed(42)

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %%
# Import the dataset
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %%
# Split the dataset into Validation and Test set
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
plt.imshow(X_train[0], cmap = "binary")
plt.axis('off')
plt.show()

# %%
y_train
# Out:
# array([7, 3, 4, ..., 5, 6, 8], dtype=uint8)

# %%
X_valid.shape
# Out:
# (5000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize = (n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap = "binary", interpolation = "nearest")
        plt.axis('off')
        plt.title(y_train[index], fontsize = 12)
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)
plt.show()

# %% [markdown]
# ### Build a simple dense network and find the optimal learning rate.
#
# ### Use callback to grow the learning rate at each iteration and record the learning rate/loss at each iteration

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28, 28]),
    keras.layers.Dense(300, activation = "relu"),
    keras.layers.Dense(100, activation = "relu"),
    keras.layers.Dense(10, activation = "softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Start with a learning rate of 1e-3 and grow it by 0.5% at each iteration

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = keras.optimizers.SGD(lr = 1e-3),
              metrics = ["accuracy"])
expon_lr = ExponentialLearningRate(factor = 1.005)

# %%
history = model.fit(X_train, y_train, epochs = 1,
                    validation_data = (X_valid, y_valid),
                    callbacks = [expon_lr])
# Out:
# Train on 55000 samples, validate on 5000 samples
# 55000/55000 [==============================] - 8s 142us/sample - loss: nan - accuracy: 0.5716 - val_loss: nan - val_accuracy: 0.0958

# %% [markdown]
# ### Plot the loss as a function of the learning rate

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28, 28]),
    keras.layers.Dense(300, activation = "relu"),
    keras.layers.Dense(100, activation = "relu"),
    keras.layers.Dense(10, activation = "softmax")
])

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr = 2e-1),
              metrics = ["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "my_mnist_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# './my_mnist_logs/run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 20)
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only = True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs = 100,
                    validation_data = (X_valid, y_valid),
                    callbacks = [early_stopping_cb, checkpoint_cb, tensorboard_cb])
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/100
# 55000/55000 [==============================] - 5s 97us/sample - loss: 0.2362 - accuracy: 0.9279 - val_loss: 0.0942 - val_accuracy: 0.9726
# Epoch 2/100
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.0961 - accuracy: 0.9704 - val_loss: 0.0867 - val_accuracy: 0.9758
# Epoch 3/100
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.0660 - accuracy: 0.9796 - val_loss: 0.0746 - val_accuracy: 0.9766
# Epoch 4/100
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.0767 - val_accuracy: 0.9774
# Epoch 5/100
# 55000/55000 [==============================] - 5s 87us/sample - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.0637 - val_accuracy: 0.9812
# Epoch 6/100
# 55000/55000 [==============================] - 5s 87us/sample - loss: 0.0253 - accuracy: 0.9917 - val_loss: 0.0723 - val_accuracy: 0.9822
# Epoch 7/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0684 - val_accuracy: 0.9836
# Epoch 8/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0746 - val_accuracy: 0.9820
# Epoch 9/100
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0660 - val_accuracy: 0.9848
# Epoch 10/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0699 - val_accuracy: 0.9844
# Epoch 11/100
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0682 - val_accuracy: 0.9844
# Epoch 12/100
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0726 - val_accuracy: 0.9846
# Epoch 13/100
# 55000/55000 [==============================] - 5s 88us/sample - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0715 - val_accuracy: 0.9844
# Epoch 14/100
# 55000/55000 [==============================] - 5s 92us/sample - loss: 3.5794e-04 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9854
# Epoch 15/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 2.5471e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9852
# Epoch 16/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 2.1585e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9852
# Epoch 17/100
# 55000/55000 [==============================] - 5s 91us/sample - loss: 1.9085e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9854
# Epoch 18/100
# 55000/55000 [==============================] - 5s 91us/sample - loss: 1.7015e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9854
# Epoch 19/100
# 55000/55000 [==============================] - 5s 91us/sample - loss: 1.5464e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9856
# Epoch 20/100
# 55000/55000 [==============================] - 6s 103us/sample - loss: 1.4274e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9854
# Epoch 21/100
# 55000/55000 [==============================] - 6s 101us/sample - loss: 1.3234e-04 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9852
# Epoch 22/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 1.2344e-04 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9854
# Epoch 23/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 1.1552e-04 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9854
# Epoch 24/100
# 55000/55000 [==============================] - 5s 94us/sample - loss: 1.0933e-04 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9856
# Epoch 25/100
# 55000/55000 [==============================] - 5s 90us/sample - loss: 1.0296e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9854

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
model = keras.models.load_model("my_mnist_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.06916858150491026, 0.9796]

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_mnist_logs --port=6006
# Out:
# Reusing TensorBoard on port 6006 (pid 40976), started 0:47:06 ago. (Use '!kill 40976' to kill it.)
#       <iframe id="tensorboard-frame-e6bf03f192a28dc7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e6bf03f192a28dc7");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
